# %% [markdown]
# ## Task-1

# %%
import pandas as pd

data = {
    'Aegyptosaurus': [4, 'blue'],
    'Tyrannosaurus': [8, 'white'],
    'Panoplosaurus': [15, 'blue'],
    'Isisaurus': [16, 'purple'],
    'Triceratops': [23, 'violet'],
    'Velociraptor': [42, 'gray'],
}


df = pd.DataFrame(data, index=['Favourite Prime', 'Favourite Color'])

# %%
df
# Out:
#                 Aegyptosaurus Tyrannosaurus Panoplosaurus Isisaurus  \
# Favourite Prime             4             8            15        16
# Favourite Color          blue         white          blue    purple
#
#                 Triceratops Velociraptor
# Favourite Prime          23           42
# Favourite Color      violet         gray

# %%
df.loc['Lives in'] = "extinct"

# %%
df = df.drop('Tyrannosaurus', axis=1)

# %%
df
# Out:
#                 Aegyptosaurus Panoplosaurus Isisaurus Triceratops Velociraptor
# Favourite Prime             4            15        16          23           42
# Favourite Color          blue          blue    purple      violet         gray
# Lives in              extinct       extinct   extinct     extinct      extinct

# %%
df.shape
# Out:
# (3, 5)

# %% [markdown]
# ## Task- 2

# %%
import pandas as pd

# %%
df=pd.read_csv(r"Data/Task2Data.csv")

# %%
df
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
# 6   5      2           4             8                37.20     10     True
# 7   5      3           2             4                96.51     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# ...

# %%
df.shape
# Out:
# (8, 21)

# %%
df.head(5)
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# 3                        0.20                       40.03
# 4                        0.13                       20.93
#
#    Max. Edge Build Time / s  ...  Max. Init. Time / s  Presim. Time / s  \
# 0                     46.34  ...                 1.01              7.87
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
# 6   5      2           4             8                37.20     10     True
# 7   5      3           2             4                96.51     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# ...

# %% [markdown]
# ## Task-3

# %%
df.insert(df.shape[1] - 1, "Program_Runtime*2", df["Runtime Program / s"] * 2)

# %%
df
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
# 6   5      2           4             8                37.20     10     True
# 7   5      3           2             4                96.51     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# ...
